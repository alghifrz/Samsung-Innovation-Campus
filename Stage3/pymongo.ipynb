# %%
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) defines the connection parameters
uri = 'mongodb://node46266-mongodb.user.cloudjkt01.com:11133'
try:
    conn = MongoClient(uri)
    conn.server_info() # force connection on a request as the
                         # connect=True parameter of MongoClient seems
                         # to be useless here
except pymongo.errors.ServerSelectionTimeoutError as err:
    # do whatever you need
    print(err)

# %%
# Connect with atlas db
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) defines the connection parameters
uri = 'mongodb+srv://alghifrz:arz170604@gettingstarted.zo2se.mongodb.net/?retryWrites=true&w=majority&appName=GettingStarted'
try:
    conn = MongoClient(uri)
    conn.server_info() # force connection on a request as the
                         # connect=True parameter of MongoClient seems
                         # to be useless here
except pymongo.errors.ServerSelectionTimeoutError as err:
    # do whatever you need
    print(err)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[16], line 11
#       9 try:
#      10     conn = MongoClient(uri)
# ---> 11     conn.server_info() # force connection on a request as the
#      12                          # connect=True parameter of MongoClient seems
#      13                          # to be useless here
#      14 except pymongo.errors.ServerSelectionTimeoutError as err:
#      15     # do whatever you need
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\mongo_client.py:1922, in MongoClient.server_info(self, session)
#    1911 def server_info(self, session: Optional[client_session.ClientSession] = None) -> dict[str, Any]:
#    1912     """Get information about the MongoDB server we're connected to.
#    1913
#    1914     :param session: a
#    (...)
#    1918        Added ``session`` parameter.
#    1919     """
# ...

# %%
mydb = conn.mydatabase
mycol = mydb.sensors_data

# %%
emp_rec1 = {
        "name":"Mr.Geek",
        "eid":24,
        "location":"delhi"
        }
# Insert Data
rec_id1 = mycol.insert_one(emp_rec1)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[10], line 7
#       1 emp_rec1 = {
#       2         "name":"Mr.Geek",
#       3         "eid":24,
#       4         "location":"delhi"
#       5         }
#       6 # Insert Data
# ----> 7 rec_id1 = mycol.insert_one(emp_rec1)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
# ...
